# %%
from behavior_utils import *
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Initialize paths

# %%
root_path = 'D:/data'
experiment = 'clickbait-motivate'
events_dir = 'bonsai'
session_type = 'm'

# Get paths to relevant files
ttl_paths = get_file_paths(f"{root_path}/{experiment}/preprocessed", 'npy', 'ttl_times', session_type=session_type, print_paths=True, print_n=3)
video_paths = get_file_paths(f"{root_path}/{experiment}/{events_dir}", 'avi', '', session_type=session_type, print_paths=True, print_n=3)
timestamps = get_file_paths(f"{root_path}/{experiment}/{events_dir}", 'csv', 'timestamp', session_type=session_type, print_paths=True, print_n=3)
event_paths_a = get_file_paths(f"{root_path}/{experiment}/{events_dir}", 'csv', '_eventsA', session_type=session_type, print_paths=True, print_n=3)
event_paths_b = get_file_paths(f"{root_path}/{experiment}/{events_dir}", 'csv', '_eventsB', session_type=session_type, print_paths=True, print_n=3)
sleap_paths = get_file_paths(f"{root_path}/{experiment}/{events_dir}", 'csv', 'slp', session_type=session_type, print_paths=True, print_n=3)
sync_paths = get_file_paths(f"{root_path}/{experiment}/preprocessed", 'txt', 'sync_messages', session_type='', print_paths=True, print_n=3)
reward_paths = get_file_paths(f"{root_path}/{experiment}/preprocessed", 'npy', 'reward_state', session_type=session_type, print_paths=True, print_n=3)

# Root directory for saving processed data
save_path = Path(f"{root_path}/{experiment}/{events_dir}")
# Out:
# Found 72 ttl_times.npy files
# 0 D:\data\clickbait-motivate\preprocessed\7010\m1\ttl_times.npy
# 1 D:\data\clickbait-motivate\preprocessed\7010\m2\ttl_times.npy
# 2 D:\data\clickbait-motivate\preprocessed\7010\m4\ttl_times.npy
# Found 73 .avi files
# 0 D:\data\clickbait-motivate\bonsai\7010\m1\10082025_7010_m1.avi
# 1 D:\data\clickbait-motivate\bonsai\7010\m2\10092025_7010_m2.avi
# 2 D:\data\clickbait-motivate\bonsai\7010\m4\10132025_7010_m4.avi
# Found 73 timestamp.csv files
# 0 D:\data\clickbait-motivate\bonsai\7010\m1\10082025_7010_m1_video_timestamp.csv
# 1 D:\data\clickbait-motivate\bonsai\7010\m2\10092025_7010_m2_video_timestamp.csv
# 2 D:\data\clickbait-motivate\bonsai\7010\m4\10132025_7010_m4_video_timestamp.csv
# Found 73 _eventsA.csv files
# 0 D:\data\clickbait-motivate\bonsai\7010\m1\10082025_7010_m1_eventsA.csv
# 1 D:\data\clickbait-motivate\bonsai\7010\m2\10092025_7010_m2_eventsA.csv
# 2 D:\data\clickbait-motivate\bonsai\7010\m4\10132025_7010_m4_eventsA.csv
# Found 73 _eventsB.csv files
# 0 D:\data\clickbait-motivate\bonsai\7010\m1\10082025_7010_m1_eventsB.csv
# 1 D:\data\clickbait-motivate\bonsai\7010\m2\10092025_7010_m2_eventsB.csv
# 2 D:\data\clickbait-motivate\bonsai\7010\m4\10132025_7010_m4_eventsB.csv
# Found 73 slp.csv files
# 0 D:\data\clickbait-motivate\bonsai\7010\m1\7010_m1_slp.csv
# 1 D:\data\clickbait-motivate\bonsai\7010\m2\7010_m2_slp.csv
# 2 D:\data\clickbait-motivate\bonsai\7010\m4\7010_m4_slp.csv
# Found 74 sync_messages.txt files
# 0 D:\data\clickbait-motivate\preprocessed\7010\m1\sync_messages.txt
# 1 D:\data\clickbait-motivate\preprocessed\7010\m2\sync_messages.txt
# 2 D:\data\clickbait-motivate\preprocessed\7010\m4\sync_messages.txt
# Found 74 reward_state.npy files
# 0 D:\data\clickbait-motivate\preprocessed\7010\m1\reward_state.npy
# 1 D:\data\clickbait-motivate\preprocessed\7010\m2\reward_state.npy
# 2 D:\data\clickbait-motivate\preprocessed\7010\m4\reward_state.npy

# %%
# Make sure only paths with valid TTL files are used
video_paths = filter_paths(video_paths, ttl_paths)
timestamps = filter_paths(timestamps, ttl_paths)
event_paths_a = filter_paths(event_paths_a, ttl_paths)
event_paths_b = filter_paths(event_paths_b, ttl_paths)
sleap_paths = filter_paths(sleap_paths, ttl_paths)
sync_paths = filter_paths(sync_paths, ttl_paths)
reward_paths = filter_paths(reward_paths, ttl_paths)

print(f"Using {len(video_paths)} .avi files.")
print(f"Using {len(timestamps)} timestamp.csv files.")
print(f"Using {len(event_paths_a)} eventsA.csv files.")
print(f"Using {len(event_paths_b)} eventsB.csv files.")
print(f"Using {len(sleap_paths)} sleap.csv files.")
print(f"Using {len(sync_paths)} sync_messages.txt files.")
print(f"Using {len(reward_paths)} reward_state.npy files.")
# Out:
# Using 72 .avi files.
# Using 72 timestamp.csv files.
# Using 72 eventsA.csv files.
# Using 72 eventsB.csv files.
# Using 72 sleap.csv files.
# Using 72 sync_messages.txt files.
# Using 72 reward_state.npy files.

# %% [markdown]
# ### Dict of 'names': 'types' for event dataframe columns

# %%
columns = {'trial_number': 'uint8',
            'timestamp': 'str',
            'poke_left': 'bool',
            'poke_right': 'bool',
            'centroid_x': 'uint16',
            'centroid_y': 'uint16',
            'target_cell': 'str',
            'iti': 'bool',
            'water_left': 'bool',
            'water_right': 'bool',
            'reward_state': 'bool',
            'click': 'bool',
            'flip_state': 'bool'
            }

# %%
def find_offset(dataframe, event_bool, rising_edge=False):
    if rising_edge:
        edge = 1
    else:
        edge = -1
    # Get penultimate True->False transition in reward_state column
    reward_state_transitions = np.diff(dataframe['reward_state'].astype(int)) == edge
    transition_indices = np.where(reward_state_transitions)[0]
    penultimate_reward_transition_idx = transition_indices[-2]
    penultimate_event_time = dataframe.loc[penultimate_reward_transition_idx, 'timestamp_ms']
    
    # Get penultimate transition in event_bool
    bool_transitions = np.where(np.diff(event_bool.astype(int)) == edge)[0]
    penultimate_bool_transition_sample = bool_transitions[-2]
    
    # Calculate offset (timestamp of reward - sample number of bool transition)
    event_difference = int(penultimate_event_time) - penultimate_bool_transition_sample
    
    return event_difference

# %%
def find_offset_from_penultimate(dataframe, event_bool):
    # Get penultimate True->False transition in reward_state column
    reward_state_transitions = np.diff(dataframe['reward_state'].astype(int)) == -1
    transition_indices = np.where(reward_state_transitions)[0]
    
    # Check if we have at least 2 transitions
    if len(transition_indices) < 2:
        raise ValueError("Not enough reward_state transitions found (need at least 2)")
    
    penultimate_reward_transition_idx = transition_indices[-2]
    penultimate_event_time = dataframe.loc[penultimate_reward_transition_idx, 'timestamp_ms']
    
    # Get final timestamp from dataframe
    final_timestamp = int(dataframe['timestamp_ms'].iloc[-1])
    
    # Get penultimate 1->0 transition in event_bool BEFORE final_timestamp
    bool_transitions = np.where(np.diff(event_bool.astype(int)) == -1)[0]
    
    # Filter for transitions that occur before final_timestamp
    valid_bool_transitions = bool_transitions[bool_transitions < final_timestamp]
    
    # Check if we have at least 2 transitions
    if len(valid_bool_transitions) < 2:
        raise ValueError("Not enough event_bool transitions found (need at least 2)")
    
    penultimate_bool_transition_sample = valid_bool_transitions[-2]
    
    # Calculate offset (timestamp of reward - sample number of bool transition)
    event_difference = int(penultimate_event_time) - penultimate_bool_transition_sample
    
    return event_difference

# %% [markdown]
# ### Process events and assign TTL times to each observation

# %%
sleap = True  # Whether to include SLEAP data

for session_idx in range(len(ttl_paths)):
    try:
        ttl_times = np.load(ttl_paths[session_idx])
        reward_bool = np.load(reward_paths[session_idx])

        # Process event data from Bonsai and concatenate into a single dataframe
        event_data = process_events(session_idx, event_paths_a, event_paths_b, columns)

        oe_start_time = open_ephys_start_time(sync_paths[session_idx])  # Get Open Ephys start time
        event_data['timestamp'] = event_data['timestamp'].apply(timestamp_to_ms)  # Convert to ms
        event_data['timestamp'] = event_data['timestamp'] - int(oe_start_time)  # Align to Open Ephys start time
        event_data.rename(columns={'timestamp': 'bonsai_ts'}, inplace=True)  # Rename timestamp column

        """Align event timestamps with  Open Ephys TTL."""

        ttl_offset = len(ttl_times) - len(event_data)
        timestamp_ms =  ttl_times[ttl_offset:]
        event_data['timestamp_ms'] = timestamp_ms.astype(np.int32)

        """SLEAP"""
        # Load SLEAP tracking data and concatenate with events df
        if sleap:
            if len(sleap_paths) == len(video_paths): 
                sleap_data = pd.read_csv(f"{sleap_paths[session_idx]}")
                sleap_offset = len(sleap_data) - len(event_data)  # Video starts slightly ahead of events
                sleap_data = sleap_data[sleap_offset:].reset_index(drop=True)  # Trim to match event df length
                event_data = pd.concat([event_data, sleap_data], axis=1, join='inner')

        # Set up save path
        mouse_id = ttl_paths[session_idx].parents[1].name
        session_id = ttl_paths[session_idx].parents[0].name
        event_path = save_path / mouse_id / session_id

        # if event path doesn't exist, create it
        if not event_path.exists():
            event_path.mkdir(parents=True, exist_ok=True)

        # Save event data
        event_data.to_csv(save_path / mouse_id / session_id / f'events.csv', index=False)
        print(f"Saved events for {mouse_id} {session_id} to {save_path / mouse_id / session_id / f'events.csv'}")
    except Exception as e:
        print(f"{mouse_id}-{session_id} error: {e}")
        continue
# Out:
# Saved events for 7010 m1 to D:\data\clickbait-motivate\bonsai\7010\m1\events.csv
# Saved events for 7010 m2 to D:\data\clickbait-motivate\bonsai\7010\m2\events.csv
# Saved events for 7010 m4 to D:\data\clickbait-motivate\bonsai\7010\m4\events.csv
# Saved events for 7010 m5 to D:\data\clickbait-motivate\bonsai\7010\m5\events.csv
# Saved events for 7010 m6 to D:\data\clickbait-motivate\bonsai\7010\m6\events.csv
# Saved events for 7010 m7 to D:\data\clickbait-motivate\bonsai\7010\m7\events.csv
# Saved events for 7010 m8 to D:\data\clickbait-motivate\bonsai\7010\m8\events.csv
# Saved events for 7010 m9 to D:\data\clickbait-motivate\bonsai\7010\m9\events.csv
# Saved events for 7010 m10 to D:\data\clickbait-motivate\bonsai\7010\m10\events.csv
# Saved events for 7010 m11 to D:\data\clickbait-motivate\bonsai\7010\m11\events.csv
# Saved events for 7010 m12 to D:\data\clickbait-motivate\bonsai\7010\m12\events.csv
# Saved events for 7010 m13 to D:\data\clickbait-motivate\bonsai\7010\m13\events.csv
# Saved events for 7010 m14 to D:\data\clickbait-motivate\bonsai\7010\m14\events.csv
# Saved events for 7010 m15 to D:\data\clickbait-motivate\bonsai\7010\m15\events.csv
# Saved events for 7010 m16 to D:\data\clickbait-motivate\bonsai\7010\m16\events.csv
# Saved events for 7010 m17 to D:\data\clickbait-motivate\bonsai\7010\m17\events.csv
# Saved events for 7010 m18 to D:\data\clickbait-motivate\bonsai\7010\m18\events.csv
# Saved events for 7010 m19 to D:\data\clickbait-motivate\bonsai\7010\m19\events.csv
# Saved events for 7010 m20 to D:\data\clickbait-motivate\bonsai\7010\m20\events.csv
# Saved events for 7011 m2 to D:\data\clickbait-motivate\bonsai\7011\m2\events.csv
# Saved events for 7011 m3 to D:\data\clickbait-motivate\bonsai\7011\m3\events.csv
# Saved events for 7011 m4 to D:\data\clickbait-motivate\bonsai\7011\m4\events.csv
# Saved events for 7011 m5 to D:\data\clickbait-motivate\bonsai\7011\m5\events.csv
# Saved events for 7011 m6 to D:\data\clickbait-motivate\bonsai\7011\m6\events.csv
# Saved events for 7011 m7 to D:\data\clickbait-motivate\bonsai\7011\m7\events.csv
# Saved events for 7011 m9 to D:\data\clickbait-motivate\bonsai\7011\m9\events.csv
# Saved events for 7011 m10 to D:\data\clickbait-motivate\bonsai\7011\m10\events.csv
# Saved events for 7011 m11 to D:\data\clickbait-motivate\bonsai\7011\m11\events.csv
# Saved events for 7011 m12 to D:\data\clickbait-motivate\bonsai\7011\m12\events.csv
# Saved events for 7011 m13 to D:\data\clickbait-motivate\bonsai\7011\m13\events.csv
# 7011-m13 error: Length of values (798) does not match length of index (81836)
# Saved events for 7011 m15 to D:\data\clickbait-motivate\bonsai\7011\m15\events.csv
# Saved events for 7011 m16 to D:\data\clickbait-motivate\bonsai\7011\m16\events.csv
# Saved events for 7011 m17 to D:\data\clickbait-motivate\bonsai\7011\m17\events.csv
# Saved events for 7011 m18 to D:\data\clickbait-motivate\bonsai\7011\m18\events.csv
# Saved events for 7011 m19 to D:\data\clickbait-motivate\bonsai\7011\m19\events.csv
# Saved events for 7011 m20 to D:\data\clickbait-motivate\bonsai\7011\m20\events.csv
# Saved events for 7012 m1 to D:\data\clickbait-motivate\bonsai\7012\m1\events.csv
# Saved events for 7012 m3 to D:\data\clickbait-motivate\bonsai\7012\m3\events.csv
# Saved events for 7012 m4 to D:\data\clickbait-motivate\bonsai\7012\m4\events.csv
# Saved events for 7012 m5 to D:\data\clickbait-motivate\bonsai\7012\m5\events.csv
# Saved events for 7012 m6 to D:\data\clickbait-motivate\bonsai\7012\m6\events.csv
# Saved events for 7012 m7 to D:\data\clickbait-motivate\bonsai\7012\m7\events.csv
# Saved events for 7012 m8 to D:\data\clickbait-motivate\bonsai\7012\m8\events.csv
# Saved events for 7012 m9 to D:\data\clickbait-motivate\bonsai\7012\m9\events.csv
# Saved events for 7012 m10 to D:\data\clickbait-motivate\bonsai\7012\m10\events.csv
# Saved events for 7012 m11 to D:\data\clickbait-motivate\bonsai\7012\m11\events.csv
# Saved events for 7012 m13 to D:\data\clickbait-motivate\bonsai\7012\m13\events.csv
# Saved events for 7012 m15 to D:\data\clickbait-motivate\bonsai\7012\m15\events.csv
# Saved events for 7012 m16 to D:\data\clickbait-motivate\bonsai\7012\m16\events.csv
# Saved events for 7012 m17 to D:\data\clickbait-motivate\bonsai\7012\m17\events.csv
# 7012-m17 error: Length of values (192) does not match length of index (81693)
# Saved events for 7012 m19 to D:\data\clickbait-motivate\bonsai\7012\m19\events.csv
# Saved events for 7012 m20 to D:\data\clickbait-motivate\bonsai\7012\m20\events.csv
# Saved events for 7013 m1 to D:\data\clickbait-motivate\bonsai\7013\m1\events.csv
# Saved events for 7013 m2 to D:\data\clickbait-motivate\bonsai\7013\m2\events.csv
# Saved events for 7013 m3 to D:\data\clickbait-motivate\bonsai\7013\m3\events.csv
# Saved events for 7013 m4 to D:\data\clickbait-motivate\bonsai\7013\m4\events.csv
# Saved events for 7013 m5 to D:\data\clickbait-motivate\bonsai\7013\m5\events.csv
# Saved events for 7013 m6 to D:\data\clickbait-motivate\bonsai\7013\m6\events.csv
# Saved events for 7013 m7 to D:\data\clickbait-motivate\bonsai\7013\m7\events.csv
# Saved events for 7013 m8 to D:\data\clickbait-motivate\bonsai\7013\m8\events.csv
# Saved events for 7013 m9 to D:\data\clickbait-motivate\bonsai\7013\m9\events.csv
# Saved events for 7013 m11 to D:\data\clickbait-motivate\bonsai\7013\m11\events.csv
# Saved events for 7013 m12 to D:\data\clickbait-motivate\bonsai\7013\m12\events.csv
# Saved events for 7013 m13 to D:\data\clickbait-motivate\bonsai\7013\m13\events.csv
# Saved events for 7013 m14 to D:\data\clickbait-motivate\bonsai\7013\m14\events.csv
# Saved events for 7013 m15 to D:\data\clickbait-motivate\bonsai\7013\m15\events.csv
# Saved events for 7013 m16 to D:\data\clickbait-motivate\bonsai\7013\m16\events.csv
# Saved events for 7013 m17 to D:\data\clickbait-motivate\bonsai\7013\m17\events.csv
# Saved events for 7013 m18 to D:\data\clickbait-motivate\bonsai\7013\m18\events.csv
# Saved events for 7013 m19 to D:\data\clickbait-motivate\bonsai\7013\m19\events.csv

# %%
# flip_paths =  get_file_paths('D:/data/clickbait-motivate', extension='npy', keyword='reward_state', session_type='m', print_paths=False, print_n=20)
# events_paths = get_file_paths('D:/data/clickbait-motivate/bonsai', extension='csv', keyword='events', session_type='m', keyword_exact=True, print_paths=False, print_n=20)
# flip_paths = filter_paths(flip_paths, events_paths)

# for ii in range(len(events_paths)):
#     try:
#         # Load events data
#         event_data = pd.read_csv(events_paths[ii])

#         # Load flip state data
#         flip_state = np.load(flip_paths[ii])
#         flip_bool = flip_state > 0

#         # Find offset and apply to timestamp_ms
#         offset_pre = find_offset_from_penultimate(event_data, reward_bool)
#         event_data['timestamp_ms'] = event_data['timestamp_ms'] - offset_pre
#         offset_post = find_offset_from_penultimate(event_data, reward_bool)
#         print(f"Before offset (ms): {offset_pre} - After offset (ms): {offset_post}")

#         # Save aligned csv
#         event_data.to_csv(f"{events_paths[ii]}", index=False)
#         print(f"{ii} Saved aligned events to {events_paths[ii]}")

#     except Exception as e:
#         print(f"Error processing {events_paths[ii]}: {e}")
#         continue
# Out:
# Found 74 reward_state.npy files
# Found 73 events.csv files
# Before offset (ms): -199000 - After offset (ms): -19356
# 0 Saved aligned events to D:\data\clickbait-motivate\bonsai\7010\m1\events.csv
# Before offset (ms): -79372 - After offset (ms): 0
# 1 Saved aligned events to D:\data\clickbait-motivate\bonsai\7010\m2\events.csv
# Before offset (ms): -758224 - After offset (ms): 0
# 2 Saved aligned events to D:\data\clickbait-motivate\bonsai\7010\m4\events.csv
# Before offset (ms): -73880 - After offset (ms): 0
# 3 Saved aligned events to D:\data\clickbait-motivate\bonsai\7010\m5\events.csv
# Before offset (ms): -48463 - After offset (ms): 0
# 4 Saved aligned events to D:\data\clickbait-motivate\bonsai\7010\m6\events.csv
# Before offset (ms): -263101 - After offset (ms): 0
# 5 Saved aligned events to D:\data\clickbait-motivate\bonsai\7010\m7\events.csv
# Before offset (ms): -171872 - After offset (ms): -2246
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[135], line 21
#      18     print(f"Before offset (ms): {offset_pre} - After offset (ms): {offset_post}")
#      20     # Save aligned csv
# ---> 21     event_data.to_csv(f"{events_paths[ii]}", index=False)
#      22     print(f"{ii} Saved aligned events to {events_paths[ii]}")
#      24 except Exception as e:
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:259, in CSVFormatter.save(self)
#     240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#    (...)
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
# --> 259     self._save()
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:264, in CSVFormatter._save(self)
#     262 if self._need_to_save_header:
#     263     self._save_header()
# --> 264 self._save_body()
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:302, in CSVFormatter._save_body(self)
#     300 if start_i >= end_i:
#     301     break
# --> 302 self._save_chunk(start_i, end_i)
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:309, in CSVFormatter._save_chunk(self, start_i, end_i)
#     306 slicer = slice(start_i, end_i)
#     307 df = self.obj.iloc[slicer]
# --> 309 res = df._mgr.to_native_types(**self._number_format)
#     310 data = [res.iget_values(i) for i in range(len(res.items))]
#     312 ix = self.data_index[slicer]._format_native_types(**self._number_format)
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\managers.py:512, in BaseBlockManager.to_native_types(self, **kwargs)
#     507 def to_native_types(self: T, **kwargs) -> T:
#     508     """
#     509     Convert values to native types (strings / python objects) that are used
#     510     in formatting (repr / csv).
#     511     """
# --> 512     return self.apply("to_native_types", **kwargs)
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:531, in Block.to_native_types(self, na_rep, quoting, **kwargs)
#     528 @final
#     529 def to_native_types(self, na_rep: str = "nan", quoting=None, **kwargs) -> Block:
#     530     """convert to our native types format"""
# --> 531     result = to_native_types(self.values, na_rep=na_rep, quoting=quoting, **kwargs)
#     532     return self.make_block(result)
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2542, in to_native_types(values, na_rep, quoting, float_format, decimal, **kwargs)
#    2539 else:
#    2540     values = np.array(values, dtype="object")
# -> 2542 values[mask] = na_rep
#    2543 values = values.astype(object, copy=False)
#    2544 return values
#
# KeyboardInterrupt:
