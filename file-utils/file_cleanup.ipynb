# %%
from utils import *
import shutil

# %%
events_old = get_file_paths('D:/data/clickbait-motivate/bonsai', extension='csv', keyword='events', session_type='m', keyword_exact=True, print_paths=True, print_n=20)
# Out:
# Found 73 events.csv files
# 0 D:\data\clickbait-motivate\bonsai\7010\m1\events.csv
# 1 D:\data\clickbait-motivate\bonsai\7010\m2\events.csv
# 2 D:\data\clickbait-motivate\bonsai\7010\m4\events.csv
# 3 D:\data\clickbait-motivate\bonsai\7010\m5\events.csv
# 4 D:\data\clickbait-motivate\bonsai\7010\m6\events.csv
# 5 D:\data\clickbait-motivate\bonsai\7010\m7\events.csv
# 6 D:\data\clickbait-motivate\bonsai\7010\m8\events.csv
# 7 D:\data\clickbait-motivate\bonsai\7010\m9\events.csv
# 8 D:\data\clickbait-motivate\bonsai\7010\m10\events.csv
# 9 D:\data\clickbait-motivate\bonsai\7010\m11\events.csv
# 10 D:\data\clickbait-motivate\bonsai\7010\m12\events.csv
# 11 D:\data\clickbait-motivate\bonsai\7010\m13\events.csv
# 12 D:\data\clickbait-motivate\bonsai\7010\m14\events.csv
# 13 D:\data\clickbait-motivate\bonsai\7010\m15\events.csv
# 14 D:\data\clickbait-motivate\bonsai\7010\m16\events.csv
# 15 D:\data\clickbait-motivate\bonsai\7010\m17\events.csv
# ...

# %%
# Deelete old event files 
for path in events_old:
    path.unlink()

# %%
events_old = get_file_paths('D:/data/clickbait-motivate/bonsai', extension='csv', keyword='events', session_type='m', keyword_exact=True, print_paths=True, print_n=20)
# Out:
# Found 0 events.csv files
